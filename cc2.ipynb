# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
data=pd.read_csv('C:/raja/housepred.csv')

# %%
data
# Out:
#               id             date      price  bedrooms  bathrooms  \
# 0     7129300520  20141013T000000   221900.0         3       1.00
# 1     6414100192  20141209T000000   538000.0         3       2.25
# 2     5631500400  20150225T000000   180000.0         2       1.00
# 3     2487200875  20141209T000000   604000.0         4       3.00
# 4     1954400510  20150218T000000   510000.0         3       2.00
# ...          ...              ...        ...       ...        ...
# 9994  6738700335  20140701T000000  1700000.0         4       2.75
# 9995   322059264  20140926T000000   279000.0         2       1.00
# 9996  5557500270  20150209T000000   262000.0         3       1.50
# 9997  9164100125  20140807T000000   533000.0         4       1.00
# 9998  7370600045  20150402T000000   640000.0         3       1.75
#
#       sqft_living  sqft_lot  floors  waterfront  view  ...  grade  sqft_above  \
# 0            1180      5650     1.0           0     0  ...      7        1180
# 1            2570      7242     2.0           0     0  ...      7        2170
# 2             770     10000     1.0           0     0  ...      6         770
# 3            1960      5000     1.0           0     0  ...      7        1050
# 4            1680      8080     1.0           0     0  ...      8        1680
# ...           ...       ...     ...         ...   ...  ...    ...         ...
# 9994         3770     10900     2.0           0     2  ...      9        3070
# 9995         1020     47044     1.0           0     0  ...      7        1020
# 9996         1700      9579     1.0           0     0  ...      7        1100
# 9997         1550      4750     1.5           0     0  ...      7        1550
# 9998         1680      8100     1.0           0     2  ...      8        1680
#
#       sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 0                 0      1955             0    98178  47.5112 -122.257
# 1               400      1951          1991    98125  47.7210 -122.319
# 2                 0      1933             0    98028  47.7379 -122.233
# 3               910      1965             0    98136  47.5208 -122.393
# 4                 0      1987             0    98074  47.6168 -122.045
# ...             ...       ...           ...      ...      ...      ...
# 9994            700      1924             0    98144  47.5849 -122.290
# 9995              0      1904          1958    98042  47.4206 -122.155
# 9996            600      1962             0    98023  47.3209 -122.338
# 9997              0      1919             0    98117  47.6824 -122.389
# 9998              0      1950             0    98177  47.7212 -122.364
#
#       sqft_living15  sqft_lot15
# 0              1340        5650
# 1              1690        7639
# 2              2720        8062
# 3              1360        5000
# 4              1800        7503
# ...             ...         ...
# 9994           3000        5000
# 9995           1930       12139
# 9996           1700        9628
# 9997           1320        4750
# 9998           1880        7750
#
# [9999 rows x 21 columns]

# %%
data.shape
# Out:
# (9999, 21)

# %%
data.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503
#
# [5 rows x 21 columns]

# %%
data.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
X=data[['bedrooms','sqft_living15','zipcode','yr_built','bathrooms','floors','grade']]
y=data['price']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=42)

# %%
X_train
# Out:
#       bedrooms  sqft_living15  zipcode  yr_built  bathrooms  floors  grade
# 4900         3           2850    98075      1971       1.75     1.0      8
# 4375         4           2080    98118      1960       2.00     1.0      7
# 7296         4           1830    98028      1978       2.50     2.0      8
# 9804         3           1970    98019      2003       2.50     2.0      7
# 1101         5           1320    98122      1905       2.00     2.0      7
# ...        ...            ...      ...       ...        ...     ...    ...
# 5734         4           1760    98022      1980       2.50     1.0      7
# 5191         3           2110    98042      1989       2.50     2.0      8
# 5390         3           1690    98053      2004       2.50     2.0      7
# 860          1           1170    98168      1963       0.75     1.0      5
# 7270         4           4770    98074      1998       3.50     2.0     12
#
# [7499 rows x 7 columns]

# %%
X_test
# Out:
#       bedrooms  sqft_living15  zipcode  yr_built  bathrooms  floors  grade
# 5344         3           2820    98155      1976       2.25     1.0      8
# 7444         3           1690    98028      1991       2.50     1.0      7
# 1731         3           1030    98108      1919       1.75     1.0      7
# 8719         4           1890    98011      1977       2.25     1.0      8
# 4521         3           1430    98103      2005       2.25     3.0      8
# ...        ...            ...      ...       ...        ...     ...    ...
# 5009         3           1730    98125      1949       3.00     1.5      7
# 7053         4           3380    98052      1995       2.75     2.0     10
# 5903         3           1680    98144      1904       1.00     1.5      6
# 9870         3           2440    98109      1904       2.00     1.5      7
# 73           4           2420    98038      2005       2.50     2.0      8
#
# [2500 rows x 7 columns]

# %%
log=LinearRegression().fit(X_train,y_train)

# %%
print(log.score(X_train,y_train))
# Out:
# 0.5652570974798371

# %%
print(log.score(X_test,y_test))
# Out:
# 0.5601217327384338

# %%
y_pred=log.predict(X_test)

# %%
df1=pd.DataFrame({'y_actual':y_test,'y_predicted':y_pred})

# %%
df1
# Out:
#       y_actual   y_predicted
# 5344  482975.0  6.820808e+05
# 7444  390000.0  3.503236e+05
# 1731  337000.0  5.349746e+05
# 8719  525000.0  5.470851e+05
# 4521  407000.0  3.841895e+05
# ...        ...           ...
# 5009  419950.0  6.325563e+05
# 7053  940000.0  1.013573e+06
# 5903  350000.0  4.271225e+05
# 9870  885000.0  8.026390e+05
# 73    360000.0  5.047210e+05
#
# [2500 rows x 2 columns]

# %%
X_test.shape
# Out:
# (2500, 7)

# %%
y_test.shape
# Out:
# (2500,)

# %%
y_pred.shape
# Out:
# (2500,)

# %%
plt.scatter(y_test, y_pred, color='blue')
plt.xlabel('Actual Price')
plt.ylabel('Predicted Price')
plt.title('Actual vs Predicted House Prices')
plt.show()
